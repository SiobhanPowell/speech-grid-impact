# %% [markdown]
# # Main Results - Dispatch
#
# Developed by Siobhan Powell, 2021.

# %%
import os
os.chdir('..')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import scipy
import os.path
import pandas
import matplotlib
import shutil
import copy

from simple_dispatch import generatorData
from simple_dispatch import bidStack
from simple_dispatch import dispatch
from simple_dispatch import generatorDataShort
from future_grid import FutureDemand
from future_grid import FutureGrid
from simple_dispatch import StorageModel

# %% [markdown]
# # Load Generator Model

# %%
gd_short = pickle.load(open('IntermediateOutputs/generator_data_short_WECC_2019.obj', 'rb'))

# %% [markdown]
# # Dispatch Main Grid Scenario
#
# Wind and Solar 2.5X 2019 levels

# %%
max_rate = 10000 # assumes average 4 hour storage 
cap = 40000

# Load capacity result so know if need to cover with storage
maxpen_results2 = pd.read_csv('Results/max_penetration_levels_1h_20211119.csv', index_col=0)
maxpen_results4 = pd.read_csv('Results/max_penetration_levels_1h_storagebefore_bigger_20211119.csv', index_col=0)

timer_names = {'':'Timers9pm', '_midnighttimer':'Timers12am', '_NoTimers':'TimersNone'}

for fuel in [1]: # Do not change fuel prices
    for solar, wind in {2.5:2.5}.items(): # Medium renewables scenario
        for ev_scenario in ['UniversalHome', 'HighHome', 'LowHome_HighWork', 'LowHome_LowWork']: # Access scenarios
            # no workplace control
            ev_workplace_bool=False
            # Timers:
            for i, ev_timers in enumerate(['', '_midnighttimer', '_NoTimers']):
                ev_scenario_date = '20211119'
                penlevel = 1.0
                
                # Load and set-up future grid and demand model 
                grid = FutureGrid(gd_short)
                grid.set_up_scenario(year=2030, solar=solar, wind=wind, fuel=fuel, ev_scenario=ev_scenario, ev_timers=ev_timers, ev_pen=penlevel, 
                                     ev_workplace_control='', ev_workplace_bool=False, evs_bool=True, ev_scenario_date=ev_scenario_date, 
                                     weekend_date=ev_scenario_date,  weekend_timers=ev_timers)
                # Naming convention for saved results
                if solar == 2.5:
                    save_str = 'Results/Fuel1_Solar25_Wind25/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_noWPcontrol'+'_penlevel'+str(penlevel)
                elif solar == 1:
                    save_str = 'Results/Fuel1_Solar1_Wind1/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_noWPcontrol'+'_penlevel'+str(penlevel)
                else:
                    save_str = 'Results/Fuel1_Solar5_Wind5/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_noWPcontrol'+'_penlevel'+str(penlevel)
                str1 = 'fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_noWPcontrol'
                # Check if sufficient capacity
                max_penlevel = maxpen_results2.loc[timer_names[ev_timers], str1]
                print(save_str)
                # Check for overgeneration
                grid.check_overgeneration(save_str=save_str)
                # Run dispatch
                grid.run_dispatch(max_penlevel, save_str, result_date='20211119') 
                
                # Case with 10GW storage before
                grid = FutureGrid(gd_short)
                grid.set_up_scenario(year=2030, solar=solar, wind=wind, fuel=fuel, ev_scenario=ev_scenario, 
                                     ev_timers=ev_timers, ev_pen=penlevel, ev_workplace_control='', ev_workplace_bool=False, evs_bool=True, 
                                     ev_scenario_date=ev_scenario_date, weekend_date=ev_scenario_date,  weekend_timers=ev_timers)
                
                if solar == 2.5:
                    save_str = 'Results/Fuel1_Solar25_Wind25/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_noWPcontrol'+'_penlevel'+str(penlevel)+'_storagebefore'
                elif solar == 1:
                    save_str = 'Results/Fuel1_Solar1_Wind1/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_noWPcontrol'+'_penlevel'+str(penlevel)+'_storagebefore'
                else:
                    save_str = 'Results/Fuel1_Solar5_Wind5/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_noWPcontrol'+'_penlevel'+str(penlevel)+'_storagebefore'
                grid.check_overgeneration(save_str=save_str)
                # Run storage before dispatch: 
                grid.run_storage_before_capacitydispatch(cap, max_rate)
                grid.storage.df.to_csv(save_str+'_storagebeforedf_'+'20211119'+'.csv')
                
                str1 = 'fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_noWPcontrol'
                max_penlevel = maxpen_results4.loc[timer_names[ev_timers], str1]
                print(save_str)
                # Change demand dispatched to fossil fuel generators based on storage operations:
                grid.future.demand['demand'] = np.copy(grid.storage.df.comb_demand_after_storage.values)
                grid.run_dispatch(max_penlevel, save_str, result_date='20211119') 
                    
            # workplace control - repeat above without timers but with workplace controls
            ev_workplace_bool=True
            for wp_control in ['avgem', 'minpeak']:
                ev_timers = '_NoTimers'
                ev_scenario_date = '20211119'

                penlevel = 1.0
                grid = FutureGrid(gd_short)
                grid.set_up_scenario(year=2030, solar=solar, wind=wind, fuel=fuel, ev_scenario=ev_scenario, 
                                                        ev_timers=ev_timers, ev_pen=penlevel, ev_workplace_control=wp_control, ev_workplace_bool=True, evs_bool=True, 
                                                        ev_scenario_date=ev_scenario_date, weekend_date=ev_scenario_date,  weekend_timers=ev_timers)
                if solar == 2.5:
                    save_str = 'Results/Fuel1_Solar25_Wind25/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)
                elif solar == 1:
                    save_str = 'Results/Fuel1_Solar1_Wind1/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)
                else:
                    save_str = 'Results/Fuel1_Solar5_Wind5/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)

                str1 = 'fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_WPcontrol_'+wp_control
                max_penlevel = maxpen_results2.loc[timer_names[ev_timers], str1]
                print(save_str)
                
                grid.check_overgeneration(save_str=save_str)
                grid.run_dispatch(max_penlevel, save_str, result_date='20211119')
                
                # storage before
                grid = FutureGrid(gd_short)
                grid.set_up_scenario(year=2030, solar=solar, wind=wind, fuel=fuel, ev_scenario=ev_scenario, 
                                                        ev_timers=ev_timers, ev_pen=penlevel, ev_workplace_control=wp_control, ev_workplace_bool=True, evs_bool=True, 
                                                        ev_scenario_date=ev_scenario_date, weekend_date=ev_scenario_date,  weekend_timers=ev_timers)

                if solar == 2.5:
                    save_str = 'Results/Fuel1_Solar25_Wind25/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)+'_storagebefore'
                elif solar == 1:
                    save_str = 'Results/Fuel1_Solar1_Wind1/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)+'_storagebefore'
                else:
                    save_str = 'Results/Fuel1_Solar5_Wind5/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)+'_storagebefore'
                grid.check_overgeneration(save_str=save_str)
                grid.run_storage_before_capacitydispatch(cap, max_rate)
                grid.storage.df.to_csv(save_str+'_storagebeforedf_'+'20211119'+'.csv')
                
                str1 = 'fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_WPcontrol_'+wp_control
                max_penlevel = maxpen_results4.loc[timer_names[ev_timers], str1]
                print(save_str)
                grid.future.demand['demand'] = np.copy(grid.storage.df.comb_demand_after_storage.values)
                grid.run_dispatch(max_penlevel, save_str, result_date='20211119')
# Out:
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_Timers9pm_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 21380
# Storage Capacity:  85523
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 11380
# Storage Capacity:  45523
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_Timers12am_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 8107
# Storage Capacity:  32428
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_TimersNone_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 10496
# Storage Capacity:  41987
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 497
# Storage Capacity:  1988
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_TimersNone_WPcontrol_avgem_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 10492
# Storage Capacity:  41970
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 492
# Storage Capacity:  1970
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_TimersNone_WPcontrol_minpeak_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 11069
# Storage Capacity:  44277
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_UniversalHome_TimersNone_WPcontrol_minpeak_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 1069
# Storage Capacity:  4278
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_Timers9pm_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 12373
# Storage Capacity:  49495
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 2373
# Storage Capacity:  9495
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_Timers12am_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 3313
# Storage Capacity:  13253
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_TimersNone_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 5145
# Storage Capacity:  20582
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_TimersNone_WPcontrol_avgem_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 5067
# Storage Capacity:  20270
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_TimersNone_WPcontrol_minpeak_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 6671
# Storage Capacity:  26686
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_HighHome_TimersNone_WPcontrol_minpeak_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_Timers9pm_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 2679
# Storage Capacity:  10719
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_Timers12am_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 2674
# Storage Capacity:  10699
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_TimersNone_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 3104
# Storage Capacity:  12418
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_TimersNone_WPcontrol_avgem_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 8251
# Storage Capacity:  33005
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_TimersNone_WPcontrol_minpeak_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 7635
# Storage Capacity:  30540
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_HighWork_TimersNone_WPcontrol_minpeak_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_Timers9pm_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 2750
# Storage Capacity:  11003
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_Timers12am_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 2747
# Storage Capacity:  10989
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_TimersNone_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 3294
# Storage Capacity:  13177
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_TimersNone_WPcontrol_avgem_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 3201
# Storage Capacity:  12804
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_TimersNone_WPcontrol_minpeak_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 5884
# Storage Capacity:  23539
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_LowHome_LowWork_TimersNone_WPcontrol_minpeak_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_UniversalHome_Timers9pm_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 10185
# Storage Capacity:  40743
# Solving optimization.
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_UniversalHome_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# Error!
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 186
# Storage Capacity:  744
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_UniversalHome_Timers12am_noWPcontrol_penlevel1.0
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# Error!
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 21
# Storage Capacity:  84
# Solving optimization.
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_UniversalHome_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_UniversalHome_TimersNone_noWPcontrol_penlevel1.0
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_UniversalHome_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_UniversalHome_TimersNone_WPcontrol_avgem_penlevel1.0
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_UniversalHome_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_UniversalHome_TimersNone_WPcontrol_minpeak_penlevel1.0
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# ...
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_LowHome_LowWork_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_LowHome_LowWork_TimersNone_noWPcontrol_penlevel1.0
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_LowHome_LowWork_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_LowHome_LowWork_TimersNone_WPcontrol_avgem_penlevel1.0
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_LowHome_LowWork_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_LowHome_LowWork_TimersNone_WPcontrol_minpeak_penlevel1.0
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_LowHome_LowWork_TimersNone_WPcontrol_minpeak_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_UniversalHome_Timers9pm_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 36826
# Storage Capacity:  147305
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_UniversalHome_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 26826
# Storage Capacity:  107305
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_UniversalHome_Timers12am_noWPcontrol_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 30936
# Storage Capacity:  123747
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_UniversalHome_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-cdb96386210d> in <module>
#      51
#      52                 future.demand['demand'] = np.copy(stor_df.comb_demand_after_storage.values)
# ---> 53                 run_dispatch(gd_short_copy, future, max_penlevel, save_str, result_date='20211119')
#      54
#      55             # workplace control
#
# <ipython-input-60-5e40475ba7d4> in run_dispatch(gd_short_copy, future, max_penlevel, save_str, result_date, return_generator_limits)
#     110         print('Try with storage:')
#     111         dp = dispatch(bs, future.demand, time_array=scipy.arange(52)+1, include_storage=True)
# --> 112         dp.calcDispatchAll()
#     113         if save_str is not None:
#     114             dp.df.to_csv(save_str+'_withstorage'+'_dpdf_'+result_date+'.csv', index=False)
#
# ~/Documents/SimpleDispatch/FirstVersion/simple_dispatch-master/GridModel_GridImpact/simple_dispatch.py in calcDispatchAll(self)
#    1752                 bs_mdt_dict = {}
#    1753                 #for each unique demand_threshold
# -> 1754                 for dt in events_mdt_coal_t.demand_threshold.unique():
#    1755                     #create an updated version of gd.df
#    1756                     gd_df_mdt_temp = self.bs.df_0.copy()
#
# ~/Documents/SimpleDispatch/FirstVersion/simple_dispatch-master/GridModel_GridImpact/simple_dispatch.py in updateDf(self, new_data_frame)
#     897         if dropNucHydroGeo:
#     898             self.dropNuclearHydroGeo()
# --> 899         self.addFuelColor()
#     900         self.processData()
#     901
#
# ~/Documents/SimpleDispatch/FirstVersion/simple_dispatch-master/GridModel_GridImpact/simple_dispatch.py in processData(self)
#     923         self.nox_dol_per_kg = nox_price_new
#     924         self.coal_dol_per_mmbtu = coal_price_new
# --> 925
#     926
#     927     def processData(self):
#
# ~/Documents/SimpleDispatch/FirstVersion/simple_dispatch-master/GridModel_GridImpact/simple_dispatch.py in createTotalInterpolationFunctions(self)
#    1042         if self.include_easiur:
#    1043             self.f_totalDmg_Coal = scipy.interpolate.interp1d(test.demand, (test['mw' + str(self.time)] * test['dmg' + str(self.time)] * test['is_coal']).cumsum())
# -> 1044         #fuel mix
#    1045         self.f_totalGas = scipy.interpolate.interp1d(test.demand, (test['is_gas'] * test['mw' + str(self.time)]).cumsum())
#    1046         self.f_totalCoal = scipy.interpolate.interp1d(test.demand, (test['is_coal'] * test['mw' + str(self.time)]).cumsum())
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/interpolate/interpolate.py in __init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     429                  assume_sorted=False):
#     430         """ Initialize a 1D linear interpolation class."""
# --> 431         _Interpolator1D.__init__(self, x, y, axis=axis)
#     432
#     433         self.bounds_error = bounds_error  # used by fill_value setter
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/interpolate/polyint.py in __init__(self, xi, yi, axis)
#      58         self.dtype = None
#      59         if yi is not None:
# ---> 60             self._set_yi(yi, xi=xi, axis=axis)
#      61
#      62     def __call__(self, x):
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/interpolate/polyint.py in _set_yi(self, yi, xi, axis)
#     117             raise ValueError("no interpolation axis specified")
#     118
# --> 119         yi = np.asarray(yi)
#     120
#     121         shape = yi.shape
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __array__(self, dtype)
#     933         if (
#     934             dtype is None
# --> 935             and isinstance(self.array, ABCDatetimeArray)
#     936             and getattr(self.dtype, "tz", None)
#     937         ):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in array(self)
#     910             from pandas.core.arrays.numpy_ import PandasArray
#     911
# --> 912             result = PandasArray(result)
#     913
#     914         return result
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py in __init__(self, values, copy)
#     133
#     134         self._ndarray = values
# --> 135         self._dtype = PandasDtype(values.dtype)
#     136
#     137     @classmethod
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py in __init__(self, dtype)
#      40         dtype = np.dtype(dtype)
#      41         self._dtype = dtype
# ---> 42         self._name = dtype.name
#      43         self._type = dtype.type
#      44
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_dtype.py in _name_get(dtype)
#     345
#     346     # append bit counts
# --> 347     if _name_includes_bit_suffix(dtype):
#     348         name += "{}".format(dtype.itemsize * 8)
#     349
#
# KeyboardInterrupt:

# %% [markdown]
# # Dispatch Business As Usual Scenario

# %%
max_rate = 10000 # assumes average 4 hour storage - note high uncertainty
cap = 40000

maxpen_results2 = pd.read_csv('Results/max_penetration_levels_1h_bau_20211119.csv', index_col=0)
maxpen_results4 = pd.read_csv('Results/max_penetration_levels_1h_storagebefore_bigger_bau_20211119.csv', index_col=0)

for fuel in [1]:
    for solar, wind in {2.5:2.5, 5:5, 1:1}.items():
        for ev_scenario in ['BusinessAsUsual']:
            ev_workplace_bool=True
            ev_timers=''
            ev_scenario_date='20211119'
            penlevel = 1.0
            wp_control = 'minpeak'
            grid = FutureGrid(gd_short)
            grid.set_up_scenario(year=2030, solar=solar, wind=wind, fuel=fuel, ev_scenario=ev_scenario, 
                                                    ev_timers=ev_timers, ev_pen=penlevel, ev_workplace_control=wp_control, ev_workplace_bool=True, evs_bool=True, 
                                                    ev_scenario_date=ev_scenario_date, weekend_date=ev_scenario_date,  weekend_timers=ev_timers)
            if solar == 2.5:
                save_str = 'Results/Fuel1_Solar25_Wind25/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+'TimersMixed'+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)
            elif solar == 1:
                save_str = 'Results/Fuel1_Solar1_Wind1/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+'TimersMixed'+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)
            else:
                save_str = 'Results/Fuel1_Solar5_Wind5/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+'TimersMixed'+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)
            
            str1 = 'fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_WPcontrol_'+wp_control
            max_penlevel = maxpen_results2.loc['TimersMixed', str1]
            print(save_str)
            grid.check_overgeneration(save_str=save_str)
            grid.run_dispatch(max_penlevel, save_str, result_date='20211119')                
            
            # storage before
            grid = FutureGrid(gd_short)
            grid.set_up_scenario(year=2030, solar=solar, wind=wind, fuel=fuel, ev_scenario=ev_scenario, 
                                                    ev_timers=ev_timers, ev_pen=penlevel, ev_workplace_control=wp_control, ev_workplace_bool=True, evs_bool=True, 
                                                    ev_scenario_date=ev_scenario_date, weekend_date=ev_scenario_date,  weekend_timers=ev_timers)

            if solar == 2.5:
                save_str = 'Results/Fuel1_Solar25_Wind25/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+'TimersMixed'+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)+'_storagebefore'
            elif solar == 1:
                save_str = 'Results/Fuel1_Solar1_Wind1/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+'TimersMixed'+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)+'_storagebefore'
            else:
                save_str = 'Results/Fuel1_Solar5_Wind5/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+'TimersMixed'+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)+'_storagebefore'
            grid.check_overgeneration(save_str=save_str)
            grid.run_storage_before_capacitydispatch(cap, max_rate)
            grid.storage.df.to_csv(save_str+'_storagebeforedf_'+'20211119'+'.csv')

            str1 = 'fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_WPcontrol_'+wp_control
            max_penlevel = maxpen_results4.loc['TimersMixed', str1]
            print(save_str)
            grid.future.demand['demand'] = np.copy(grid.storage.df.comb_demand_after_storage.values)
            grid.run_dispatch(max_penlevel, save_str, result_date='20211119')
# Out:
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_BusinessAsUsual_TimersMixed_WPcontrol_minpeak_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 5185
# Storage Capacity:  20743
# Solving optimization.
# Results/Fuel1_Solar25_Wind25/fuel1_solar2.5_wind2.5_BusinessAsUsual_TimersMixed_WPcontrol_minpeak_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_BusinessAsUsual_TimersMixed_WPcontrol_minpeak_penlevel1.0
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Results/Fuel1_Solar5_Wind5/fuel1_solar5_wind5_BusinessAsUsual_TimersMixed_WPcontrol_minpeak_penlevel1.0_storagebefore
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_BusinessAsUsual_TimersMixed_WPcontrol_minpeak_penlevel1.0
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 35012
# Storage Capacity:  140051
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_BusinessAsUsual_TimersMixed_WPcontrol_minpeak_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 25012
# Storage Capacity:  100051

# %% [markdown]
# # Dispatch alternative grid models
#
# Wind and solar 1X or 5X 2019 levels

# %%
max_rate = 10000 # assumes average 4 hour storage 
cap = 40000

maxpen_results2 = pd.read_csv('Results/max_penetration_levels_1h_20211119.csv', index_col=0)
maxpen_results4 = pd.read_csv('Results/max_penetration_levels_1h_storagebefore_bigger_20211119.csv', index_col=0)

timer_names = {'':'Timers9pm', '_midnighttimer':'Timers12am', '_NoTimers':'TimersNone'}
for fuel in [1]:
    for solar, wind in {5:5, 1:1}.items():
        for ev_scenario in ['UniversalHome', 'HighHome', 'LowHome_HighWork', 'LowHome_LowWork']:
            # no workplace control
            ev_workplace_bool=False
            for i, ev_timers in enumerate(['', '_midnighttimer', '_NoTimers']):
                ev_scenario_date = '20211119'

                penlevel = 1.0
                # storage before
                grid = FutureGrid(gd_short)
                grid.set_up_scenario(year=2030, solar=solar, wind=wind, fuel=fuel, ev_scenario=ev_scenario, 
                                                                                ev_timers=ev_timers, ev_pen=penlevel, ev_workplace_control='', ev_workplace_bool=False, evs_bool=True, 
                                                                                ev_scenario_date=ev_scenario_date, weekend_date=ev_scenario_date,  weekend_timers=ev_timers)
                
                if solar == 2.5:
                    save_str = 'Results/Fuel1_Solar25_Wind25/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_noWPcontrol'+'_penlevel'+str(penlevel)+'_storagebefore'
                elif solar == 1:
                    save_str = 'Results/Fuel1_Solar1_Wind1/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_noWPcontrol'+'_penlevel'+str(penlevel)+'_storagebefore'
                else:
                    save_str = 'Results/Fuel1_Solar5_Wind5/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_noWPcontrol'+'_penlevel'+str(penlevel)+'_storagebefore'
                grid.check_overgeneration(save_str=save_str)
                grid.run_storage_before_capacitydispatch(cap, max_rate)
                grid.storage.df.to_csv(save_str+'_storagebeforedf_'+'20211119'+'.csv')
                
                str1 = 'fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_noWPcontrol'
                max_penlevel = maxpen_results4.loc[timer_names[ev_timers], str1]
                print(save_str)
                
                grid.future.demand['demand'] = np.copy(grid.storage.df.comb_demand_after_storage.values)
                grid.run_dispatch(max_penlevel, save_str, result_date='20211119')  
                    
            # workplace control
            ev_workplace_bool=True
            for wp_control in ['avgem', 'minpeak']:
                ev_timers = '_NoTimers'
                ev_scenario_date = '20211119'

                penlevel = 1.0
                # storage before
                grid = FutureGrid(gd_short)
                grid.set_up_scenario(year=2030, solar=solar, wind=wind, fuel=fuel, ev_scenario=ev_scenario, 
                                                        ev_timers=ev_timers, ev_pen=penlevel, ev_workplace_control=wp_control, ev_workplace_bool=True, evs_bool=True, 
                                                        ev_scenario_date=ev_scenario_date, weekend_date=ev_scenario_date,  weekend_timers=ev_timers)

                if solar == 2.5:
                    save_str = 'Results/Fuel1_Solar25_Wind25/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)+'_storagebefore'
                elif solar == 1:
                    save_str = 'Results/Fuel1_Solar1_Wind1/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)+'_storagebefore'
                else:
                    save_str = 'Results/Fuel1_Solar5_Wind5/fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_'+timer_names[ev_timers]+'_WPcontrol_'+wp_control+'_penlevel'+str(penlevel)+'_storagebefore'
                grid.check_overgeneration(save_str=save_str)
                grid.run_storage_before_capacitydispatch(cap, max_rate)
                grid.storage.df.to_csv(save_str+'_storagebeforedf_'+'20211119'+'.csv')
                
                str1 = 'fuel'+str(fuel)+'_solar'+str(solar)+'_wind'+str(wind)+'_'+ev_scenario+'_WPcontrol_'+wp_control
                max_penlevel = maxpen_results4.loc[timer_names[ev_timers], str1]
                print(save_str)
                grid.future.demand['demand'] = np.copy(grid.storage.df.comb_demand_after_storage.values)
                grid.run_dispatch(max_penlevel, save_str, result_date='20211119')
# Out:
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_UniversalHome_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 26826
# Storage Capacity:  107305
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_UniversalHome_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 20936
# Storage Capacity:  83747
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_UniversalHome_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 24148
# Storage Capacity:  96595
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_UniversalHome_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 25931
# Storage Capacity:  103726
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_UniversalHome_TimersNone_WPcontrol_minpeak_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 25926
# Storage Capacity:  103704
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_HighHome_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 28331
# Storage Capacity:  113324
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_HighHome_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 21876
# Storage Capacity:  87507
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_HighHome_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 26331
# Storage Capacity:  105326
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_HighHome_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 27718
# Storage Capacity:  110874
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_HighHome_TimersNone_WPcontrol_minpeak_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 26290
# Storage Capacity:  105160
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_HighWork_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 37840
# Storage Capacity:  151363
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_HighWork_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 37039
# Storage Capacity:  148156
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_HighWork_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 37834
# Storage Capacity:  151337
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_HighWork_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 39921
# Storage Capacity:  159685
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_HighWork_TimersNone_WPcontrol_minpeak_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 37708
# Storage Capacity:  150832
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_LowWork_Timers9pm_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 35595
# Storage Capacity:  142381
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_LowWork_Timers12am_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 34552
# Storage Capacity:  138211
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_LowWork_TimersNone_noWPcontrol_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 35521
# Storage Capacity:  142085
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_LowWork_TimersNone_WPcontrol_avgem_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 36691
# Storage Capacity:  146764
# Solving optimization.
# Results/Fuel1_Solar1_Wind1/fuel1_solar1_wind1_LowHome_LowWork_TimersNone_WPcontrol_minpeak_penlevel1.0_storagebefore
# ----Capacity too low----
# Try with storage:
# 1.9% Complete
# 3.8% Complete
# 5.8% Complete
# 7.7% Complete
# 9.6% Complete
# 11.5% Complete
# 13.5% Complete
# 15.4% Complete
# 17.3% Complete
# 19.2% Complete
# 21.2% Complete
# 23.1% Complete
# 25.0% Complete
# 26.9% Complete
# 28.8% Complete
# 30.8% Complete
# 32.7% Complete
# 34.6% Complete
# 36.5% Complete
# 38.5% Complete
# 40.4% Complete
# 42.3% Complete
# 44.2% Complete
# 46.2% Complete
# 48.1% Complete
# 50.0% Complete
# 51.9% Complete
# 53.8% Complete
# 55.8% Complete
# 57.7% Complete
# 59.6% Complete
# 61.5% Complete
# 63.5% Complete
# 65.4% Complete
# 67.3% Complete
# 69.2% Complete
# 71.2% Complete
# 73.1% Complete
# 75.0% Complete
# 76.9% Complete
# 78.8% Complete
# 80.8% Complete
# 82.7% Complete
# 84.6% Complete
# 86.5% Complete
# 88.5% Complete
# 90.4% Complete
# 92.3% Complete
# 94.2% Complete
# 96.2% Complete
# 98.1% Complete
# 100.0% Complete
# Solving optimization.
# Storage Rate Result: 35477
# Storage Capacity:  141909
